# %%
# setup library imports
import io, time, json
import requests
from pathlib import Path
from bs4 import BeautifulSoup
#from testing.testing import test

# %%
def read_api_key(filepath="api_key.txt"):
    """
    Read the Yelp API Key from file.
    
    Args:
        filepath (string): File containing API Key
    Returns:
        api_key (string): The API Key
    """
    
    # Feel free to modify this function if you are storing the API Key differently
    return Path(filepath).read_text().strip()

# %%
api_key = read_api_key()

# %%
def retrieve_html(url):
    """
    Return the raw HTML at the specified URL.

    Args:
        url (string): 

    Returns:
        status_code (integer):
        raw_html (string): the raw HTML content of the response, properly encoded according to the HTTP headers.
    """
    r = requests.get(url, auth=('user', 'pass'))   
    return (r.status_code, r.text)

# %%
#retrieve_html('https://www.yelp.com/biz/man-vs-fries-seattle-2?osq=Tacos')

# %%
def yelp_search(api_key, term, location):
    """
    Make an authenticated request to the Yelp API.

    Args:
        query (string): Search term

    Returns:
        total (integer): total number of businesses on Yelp corresponding to the query
        businesses (list): list of dicts representing each business
    """
    
    search_url = "https://api.yelp.com/v3/businesses/search"
    
    header_string = 'Bearer' + ' ' + api_key
    
    headers = {'Authorization': header_string}
    
    params = {"location": location, "term": term}
    
    response = requests.get(search_url, params = params, headers = headers)
    
    data = json.loads(response.text)
    
    return (data["total"], data["businesses"])

# %%
yelp_search(api_key, "tacos", "Seattle")
# Out:
# (1900,
#  [{'id': 'pzjQKP3PEkclhSD-mFn7jA',
#    'alias': 'tacos-chukis-seattle',
#    'name': 'Tacos Chukis',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AU2LRinK4hKGU7nnCTq73Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-chukis-seattle?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 1724,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.620570445175,
#     'longitude': -122.321262359619},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '219 Broadway E',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['219 Broadway E', 'Seattle, WA 98102']},
#    'phone': '+12069058537',
#    'display_phone': '(206) 905-8537',
#    'distance': 1196.2087504042854},
#   {'id': 'edzGkH9Fd0chJbiTCDqq1A',
#    'alias': 'carmelos-tacos-seattle-2',
#    'name': "Carmelo's Tacos",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lKT5a6P108hrtYrMxHEIQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carmelos-tacos-seattle-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 287,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6188713536994,
#     'longitude': -122.325116639028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '110 Summit Ave E',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98102',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['110 Summit Ave E', 'Seattle, WA 98102']},
#    'phone': '+12066590159',
#    'display_phone': '(206) 659-0159',
#    'distance': 1066.2470620133345},
#   {'id': 'kJxFj1sSvxCPZYoYqP8Qug',
#    'alias': 'birrieria-tijuana-burien-2',
#    'name': 'Birrieria Tijuana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pSdwKeF6Mrh1KFl_QDpkeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/birrieria-tijuana-burien-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 258,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.4878468034829,
#     'longitude': -122.349070266104},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1111 SW 128th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Burien',
#     'zip_code': '98146',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1111 SW 128th St', 'Burien, WA 98146']},
#    'phone': '+12067510031',
#    'display_phone': '(206) 751-0031',
#    'distance': 15331.124495249534},
#   {'id': 'MFP8MhZlBV2fuhOyHaF56w',
#    'alias': 'tacos-el-asadero-seattle-2',
#    'name': 'Tacos El Asadero',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MegtLYTmsvEwkP7RBAUCPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-el-asadero-seattle-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 334,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.5711591, 'longitude': -122.2928947},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3517 Rainier Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98118',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['3517 Rainier Ave S', 'Seattle, WA 98118']},
#    'phone': '+12064760793',
#    'display_phone': '(206) 476-0793',
#    'distance': 6817.223628010867},
#   {'id': 'nwrKWcWG1_g8nyUaaUwqlA',
#    'alias': 'tacos-chukis-seattle-5',
#    'name': 'Tacos Chukis',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/huHHXRboy1-VPKK376t8zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-chukis-seattle-5?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 407,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6270336126469,
#     'longitude': -122.342103158844},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '832 Dexter Ave N',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98109',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['832 Dexter Ave N', 'Seattle, WA 98109']},
#    'phone': '+12065189025',
#    'display_phone': '(206) 518-9025',
#    'distance': 525.6876927552172},
#   {'id': 'SxL7h2U6ETL8OtLKuEAzyQ',
#    'alias': 'el-taco-loco-seattle-5',
#    'name': 'El Taco Loco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fmEUssrh-adZhGOgaZ3GLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-taco-loco-seattle-5?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 56,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 47.6689099, 'longitude': -122.39315},
#    'transactions': ['delivery'],
#    'location': {'address1': '2804 NW Market St',
#     'address2': '',
#     'address3': 'Ballard Liquor Store',
#     'city': 'Seattle',
#     'zip_code': '98107',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2804 NW Market St',
#      'Ballard Liquor Store',
#      'Seattle, WA 98107']},
#    'phone': '+12063768563',
#    'display_phone': '(206) 376-8563',
#    'distance': 6481.931279388762},
#   {'id': 'd0cad0b3PtXKfn1rgjsB3g',
#    'alias': 'man-vs-fries-seattle-2',
#    'name': 'Man vs Fries',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kInsHWMxbJJnf2Hh-9eVYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/man-vs-fries-seattle-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 38,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'popuprestaurants', 'title': 'Pop-Up Restaurants'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.619533, 'longitude': -122.3473513},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '130 5th Ave N',
#     'address2': None,
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98109',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['130 5th Ave N', 'Seattle, WA 98109']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1109.992476597566},
#   {'id': 'R0UbUccNRf4B0V-JN4NQ-A',
#    'alias': 'taco-city-taqueria-seattle',
#    'name': 'Taco City Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mnEgXbujIemtZs5x26gtmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-city-taqueria-seattle?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 39,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.55578011014857,
#     'longitude': -122.28291141165755},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '5212 Rainier Ave S',
#     'address2': None,
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98118',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['5212 Rainier Ave S', 'Seattle, WA 98118']},
#    'phone': '+12067172170',
#    'display_phone': '(206) 717-2170',
#    'distance': 8690.269226960912},
#   {'id': 'uxsMJz_L4W2uHViwWi9KRA',
#    'alias': 'taqueria-la-fondita-2-seattle',
#    'name': 'Taqueria La Fondita #2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IFGbzqBBriJkrPx7hVH0iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-la-fondita-2-seattle?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 337,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.51516, 'longitude': -122.35435},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9811 15th Ave SW',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98106',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['9811 15th Ave SW', 'Seattle, WA 98106']},
#    'phone': '+12065510529',
#    'display_phone': '(206) 551-0529',
#    'distance': 12340.712070300066},
#   {'id': 'N2E6bOyKqwHWClwVTYPaEA',
#    'alias': 'carnitas-michoacan-seattle-2',
#    'name': 'Carnitas Michoacan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GTdDtHcYEHHSoOFvNIvvrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/carnitas-michoacan-seattle-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 138,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.58083, 'longitude': -122.31394},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2503 Beacon Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98144',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['2503 Beacon Ave S', 'Seattle, WA 98144']},
#    'phone': '+12063233688',
#    'display_phone': '(206) 323-3688',
#    'distance': 5220.00878419919},
#   {'id': 'Zn3u5r5aarfuqYPOqkgipw',
#    'alias': 'loxicha-authentic-oaxaca-cuisine-seattle',
#    'name': 'Loxicha Authentic Oaxaca Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aSYPpSInHYvZShGQpNwHmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loxicha-authentic-oaxaca-cuisine-seattle?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 103,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.71373, 'longitude': -122.31209},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '11552 15th Ave NE',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98125',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['11552 15th Ave NE', 'Seattle, WA 98125']},
#    'phone': '+12067422482',
#    'display_phone': '(206) 742-2482',
#    'distance': 9966.983107920529},
#   {'id': 'wBTCvhyi_aq0vbsB8xgBoQ',
#    'alias': 'chilolos-tacos-seattle-7',
#    'name': 'Chilolos Tacos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i3GNjxlZFj7dAxne_4Fmyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chilolos-tacos-seattle-7?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 108,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.5440817, 'longitude': -122.3291524},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '6538 4th Ave S',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98108',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['6538 4th Ave S', 'Seattle, WA 98108']},
#    'phone': '+12062574056',
#    'display_phone': '(206) 257-4056',
#    'distance': 9056.852006758028},
#   {'id': 'zAySfqDaGhW6tM4CC90NLg',
#    'alias': 'rocket-taco-seattle-2',
#    'name': 'Rocket Taco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LktZwQXznjbx_PwSeuBzdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rocket-taco-seattle-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 142,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6245287114501,
#     'longitude': -122.307003736496},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '602 19th Ave E',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98112',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['602 19th Ave E', 'Seattle, WA 98112']},
#    'phone': '+12064575355',
#    'display_phone': '(206) 457-5355',
#    'distance': 2138.66009115503},
#   {'id': 'LmFKLXK536pp77_ZKJUCLw',
#    'alias': 'lifted-taco-woodinville',
#    'name': 'Lifted Taco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_2PFaFOtI07E8AeSaKxs3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lifted-taco-woodinville?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 21,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.7522518, 'longitude': -122.1594256},
#    'transactions': [],
#    'location': {'address1': '17255 135th Ave NE',
#     'address2': 'Ste 1040',
#     'address3': '',
#     'city': 'Woodinville',
#     'zip_code': '98072',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['17255 135th Ave NE',
#      'Ste 1040',
#      'Woodinville, WA 98072']},
#    'phone': '+14254194322',
#    'display_phone': '(425) 419-4322',
#    'distance': 19303.26419958042},
#   {'id': 'JQAKcOzObl2I7vLKZLkBdQ',
#    'alias': 'fogón-cocina-mexicana-seattle-2',
#    'name': 'Fogón Cocina Mexicana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M1D-cy7HIwyvvO0deCjyDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fog%C3%B3n-cocina-mexicana-seattle-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 1512,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.6154187, 'longitude': -122.3241733},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '600 E Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98122',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['600 E Pine St', 'Seattle, WA 98122']},
#    'phone': '+12063207777',
#    'display_phone': '(206) 320-7777',
#    'distance': 1399.4662463735258},
#   {'id': 'L7EpZh_kFu8NSFrAeXY3ag',
#    'alias': 'off-the-rez-seattle',
#    'name': 'Off the Rez',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6ZPkW2UAbWbYPEJPuyQL3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/off-the-rez-seattle?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 195,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.6599202, 'longitude': -122.3118251},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4300 15th Ave NE',
#     'address2': '',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4300 15th Ave NE', 'Seattle, WA 98101']},
#    'phone': '+12064148226',
#    'display_phone': '(206) 414-8226',
#    'distance': 4269.920394305812},
#   {'id': 'wV2lc3dOoIHRT_SfmEohtA',
#    'alias': 'el-grito-taqueria-seattle',
#    'name': 'El Grito Taqueria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LQdTUiJZ42WMsErbrPnimg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-grito-taqueria-seattle?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 179,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.62069, 'longitude': -122.33398},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '234 Fairview Ave N',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98109',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['234 Fairview Ave N', 'Seattle, WA 98109']},
#    'phone': '+12066594552',
#    'display_phone': '(206) 659-4552',
#    'distance': 540.6320473729891},
#   {'id': 'ufr93TZVV457eMdCtmvffQ',
#    'alias': 'el-chapulin-oaxaqueno-seattle-2',
#    'name': 'El Chapulin Oaxaqueno',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tZBGOkb9BuwY91mo6sNR2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-chapulin-oaxaqueno-seattle-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 58,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 47.56322, 'longitude': -122.38699},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '4451 California Ave SW',
#     'address2': '',
#     'address3': None,
#     'city': 'Seattle',
#     'zip_code': '98116',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['4451 California Ave SW', 'Seattle, WA 98116']},
#    'phone': '+12067718476',
#    'display_phone': '(206) 771-8476',
#    'distance': 7920.721552549285},
#   {'id': 'Of2DnD5R93doq-5T5Qrkmw',
#    'alias': 'los-agaves-seattle-4',
#    'name': 'Los Agaves',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vSkdDbk8djRHOCa0LG2K7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-agaves-seattle-4?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 329,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.609118, 'longitude': -122.340829},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1514 Pike Place Market Ave',
#     'address2': 'Ste 7',
#     'address3': '',
#     'city': 'Seattle',
#     'zip_code': '98101',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['1514 Pike Place Market Ave',
#      'Ste 7',
#      'Seattle, WA 98101']},
#    'phone': '+12065040202',
#    'display_phone': '(206) 504-0202',
#    'distance': 1855.9150068640415},
#   {'id': 'SkkJng4iLrfP5cU-U9Y-Ag',
#    'alias': 'manus-tacos-seattle',
#    'name': "Manu's Tacos",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jl4v8y2u0ETbOU2AUBU4pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manus-tacos-seattle?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#    'review_count': 35,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 47.60022, 'longitude': -122.33131},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '240 2nd Ave S',
#     'address2': '',
#     'address3': 'Flatstick Pub',
#     'city': 'Seattle',
#     'zip_code': '98104',
#     'country': 'US',
#     'state': 'WA',
#     'display_address': ['240 2nd Ave S',
#      'Flatstick Pub',
#      'Seattle, WA 98104']},
#    'phone': '+12069145992',
#    'display_phone': '(206) 914-5992',
#    'distance': 2817.5578442272936}])

# %%
def all_restaurants(api_key, query):
    """
    Retrieve ALL the restaurants on Yelp for a given query.

    Args:
        query (string): Search term

    Returns:
        results (list): list of dicts representing each business
    """
 
    search_url = "https://api.yelp.com/v3/businesses/search"
    
    header_string = 'Bearer' + ' ' + api_key
    
    headers = {'Authorization': header_string}
    
    params1 = {"location": query, "categories" : "restaurants"}
    response1 = requests.get(search_url, params = params1, headers = headers)   
    data1 = json.loads(response1.text)

    #print(data1)
    num_records = data1['total']
    
    n = num_records//20 + 1
    offset = 0
    result = []
    for i in range(n):
        
        #20 restaurants each request
        curr_offset = offset + i*20
        params = {"location": query, "offset": curr_offset, "categories" : "restaurants"}
        response = requests.get(search_url, params = params, headers = headers)
        
        data = json.loads(response.text)
        
        #print(len(data['businesses']))
        
        #for x in data['businesses']:
            #print(x['name'])
        
        result += data["businesses"]
        time.sleep(.300)
    
    #pause slightly between requests
    
    
    return result

#data = all_restaurants(read_api_key(), 'Polish Hill, Pittsburgh')
#print(len(data))
#print([x['name'] for x in data])

# %%
tacos = all_restaurants(api_key, "Bainbridge Island")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-08e4398a3a20> in <module>
# ----> 1 tacos = all_restaurants(api_key, "Bainbridge Island")
#
# <ipython-input-10-1080d6f00f83> in all_restaurants(api_key, query)
#      40             #print(x['name'])
#      41
# ---> 42         result += data["businesses"]
#      43         time.sleep(.300)
#      44
#
# KeyError: 'businesses'

# %%
tacos
# Out:
# [{'id': 'uVsorDu2ZUVR7a1EPEA7XQ',
#   'alias': 'hickory-hole-parsons',
#   'name': 'Hickory Hole',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sWp-j6nDr7QISXRlRYP2Aw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hickory-hole-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 16,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.340157, 'longitude': -95.245848},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '720 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['720 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204219067',
#   'display_phone': '(620) 421-9067',
#   'distance': 1188.6398072372385},
#  {'id': 'EMy82JTdUU9Tl8m9xlliWQ',
#   'alias': 'kitchen-pass-restaurant-and-bar-parsons',
#   'name': 'Kitchen Pass Restaurant & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cYfFKT-SEM3cSluaEu3tJw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kitchen-pass-restaurant-and-bar-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 24,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.340743, 'longitude': -95.261394},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1711 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1711 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204211907',
#   'display_phone': '(620) 421-1907',
#   'distance': 272.93161261193865},
#  {'id': 'GIOhujdECudw5bMkjcV_hw',
#   'alias': 'el-pueblito-mexican-restaurant-parsons',
#   'name': 'El Pueblito Mexican Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e5V9puRDh5SeeV-PTmRmVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-pueblito-mexican-restaurant-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.34024, 'longitude': -95.2627399},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1804 Main St',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1804 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204213684',
#   'display_phone': '(620) 421-3684',
#   'distance': 404.1743243221859},
#  {'id': 'XeTVGhNbkvm93W-AXv198A',
#   'alias': 'remnant-cafe-parsons',
#   'name': 'Remnant Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OSdf3-i092j-7M9McfuUEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/remnant-cafe-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 10,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.34079, 'longitude': -95.26177},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1719 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1719 Main St', 'Parsons, KS 67357']},
#   'phone': '+16207174185',
#   'display_phone': '(620) 717-4185',
#   'distance': 304.5547471962812},
#  {'id': 'M3531Fd-KtsYeEAigDbS8A',
#   'alias': 'ernestos-mexican-food-parsons',
#   'name': "Ernesto's Mexican Food",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dPqKew9tT7vG1s3rBnUW1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ernestos-mexican-food-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 20,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.34171, 'longitude': -95.26439},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '200 N Central Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['200 N Central Ave', 'Parsons, KS 67357']},
#   'phone': '+16204212930',
#   'display_phone': '(620) 421-2930',
#   'distance': 480.38317953280824},
#  {'id': 'jTYCQF27aYaujD63p3ZPew',
#   'alias': 'cosmic-castle-parsons',
#   'name': 'Cosmic Castle',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G9U1wnecrELytlh0X9SXbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cosmic-castle-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 5,
#   'categories': [{'alias': 'arcades', 'title': 'Arcades'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.339993027316, 'longitude': -95.2622587233782},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '110 S 18th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['110 S 18th St', 'Parsons, KS 67357']},
#   'phone': '+16207174105',
#   'display_phone': '(620) 717-4105',
#   'distance': 385.31951317525125},
#  {'id': 'R6f-4etSmAzmeFJwpK-haw',
#   'alias': 'big-sky-bistro-parsons',
#   'name': 'Big Sky Bistro',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/big-sky-bistro-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 4,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3401185058406,
#    'longitude': -95.2564059374554},
#   'transactions': [],
#   'location': {'address1': '1500 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1500 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204212710',
#   'display_phone': '(620) 421-2710',
#   'distance': 335.73028653108474},
#  {'id': 'UWr6lC9RKo4R6XT6C4TOPQ',
#   'alias': 'pizzos-corner-parsons',
#   'name': "Pizzo's Corner",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xytWu8gPqj1PjwSjH_g81w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzos-corner-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 15,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3633235880336,
#    'longitude': -95.2589002582759},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2318 N 16th St',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2318 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204231559',
#   'display_phone': '(620) 423-1559',
#   'distance': 2336.5978149472744},
#  {'id': 'mMSPfBNAKNdpSexJRrmC9g',
#   'alias': 'chinese-chef-parsons',
#   'name': 'Chinese Chef',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chinese-chef-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 9,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3493, 'longitude': -95.25958},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '900 N 16th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['900 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204233914',
#   'display_phone': '(620) 423-3914',
#   'distance': 771.8495263767685},
#  {'id': 'KT3_y9NMyd0zj7VDaaUKEg',
#   'alias': 'granny-bs-family-diner-parsons',
#   'name': "Granny B's Family Diner",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_-kXoJWtMZaAu4jgb0VqpA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/granny-bs-family-diner-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.34005, 'longitude': -95.28019},
#   'transactions': [],
#   'location': {'address1': '2930 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2930 Main St', 'Parsons, KS 67357']},
#   'phone': '+16206056111',
#   'display_phone': '(620) 605-6111',
#   'distance': 1892.826876889311},
#  {'id': 'ZLw1CbQLTBfilFhHGobo2Q',
#   'alias': 'hortons-pizza-plus-parsons',
#   'name': 'Hortons Pizza Plus',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Gw9AqfjbFLjTqdM5gTzeeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hortons-pizza-plus-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 6,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 37.3405469398327,
#    'longitude': -95.2528686448932},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1201 Main',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1201 Main', 'Parsons, KS 67357']},
#   'phone': '+16207174174',
#   'display_phone': '(620) 717-4174',
#   'distance': 577.8993219064663},
#  {'id': 'va2Fw3pBhd9Ait5ydWJBNg',
#   'alias': 'shredders-parsons',
#   'name': 'Shredders',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-UZl2vFfpQq5zX7joT4r_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shredders-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 10,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 37.33997, 'longitude': -95.28876},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3330 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3330 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204216823',
#   'display_phone': '(620) 421-6823',
#   'distance': 2642.165708977959},
#  {'id': 'MJ5770PLJJIIyj36xyMJuw',
#   'alias': 'mcdonalds-parsons-4',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/t6HvinaFvr5a3R7cgwLjAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-parsons-4?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 11,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 37.3428193245051,
#    'longitude': -95.2586960792542},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '301 N 16th',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['301 N 16th', 'Parsons, KS 67357']},
#   'phone': '+16204210244',
#   'display_phone': '(620) 421-0244',
#   'distance': 63.355942383949596},
#  {'id': '6cx8_ztzoKPLu-TooqaL3A',
#   'alias': 'chinese-chef-parsons-2',
#   'name': 'Chinese Chef',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chinese-chef-parsons-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.349286, 'longitude': -95.259707},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '400 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['400 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204233914',
#   'display_phone': '(620) 423-3914',
#   'distance': 778.0557730132249},
#  {'id': 'c9_bHcFOT7KoNCSdxDnCOA',
#   'alias': 'taco-mayo-no-81-parsons',
#   'name': 'Taco Mayo No 81',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pa70uE2rfEASU480G9ETCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-mayo-no-81-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3399, 'longitude': -95.28612},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3210 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3210 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204216296',
#   'display_phone': '(620) 421-6296',
#   'distance': 2411.831069179789},
#  {'id': 'fTekX5M9SaYZqRafXb7igQ',
#   'alias': 'sonic-drive-in-parsons-2',
#   'name': 'Sonic Drive-In',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/quJsFcIgQyQWTQgRBZlvhA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sonic-drive-in-parsons-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3406236, 'longitude': -95.2837503},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3113 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3113 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204215440',
#   'display_phone': '(620) 421-5440',
#   'distance': 2194.461254173005},
#  {'id': 'jkIRuIkSibraDC3pewY0ew',
#   'alias': 'subway-parsons-7',
#   'name': 'Subway',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aNs1ESF06e8XChuWDm6hCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/subway-parsons-7?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3718589666557,
#    'longitude': -95.2553559134621},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3201 N 16th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3201 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204210999',
#   'display_phone': '(620) 421-0999',
#   'distance': 3301.5682264248317},
#  {'id': 'd6yseqNRFmxVlM0sROFgSg',
#   'alias': 'genko-hibachi-expres-parsons',
#   'name': 'Genko Hibachi Expres',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/genko-hibachi-expres-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.34083, 'longitude': -95.26952},
#   'transactions': [],
#   'location': {'address1': '2209 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2209 Main St', 'Parsons, KS 67357']},
#   'phone': '+16207788930',
#   'display_phone': '(620) 778-8930',
#   'distance': 939.0598108264846},
#  {'id': 'lo_OxhJ4UbhpYiklvb7Xaw',
#   'alias': 'scooters-coffee-parsons',
#   'name': 'scooters coffee',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/scooters-coffee-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3402073423643, 'longitude': -95.258048325777},
#   'transactions': [],
#   'location': {'address1': '1506 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1506 Main St', 'Parsons, KS 67357']},
#   'phone': '+16206056116',
#   'display_phone': '(620) 605-6116',
#   'distance': 249.04794013599707},
#  {'id': '8KtJ6MNfFnAyITqhNPoMhA',
#   'alias': 'pizza-hut-parsons-2',
#   'name': 'Pizza Hut',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9xAyjld5Xze6KWviJ2Xt3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizza-hut-parsons-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 37.3401759, 'longitude': -95.270229},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2230 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2230 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204213720',
#   'display_phone': '(620) 421-3720',
#   'distance': 1019.1211144375114},
#  {'id': 'AGCcO8zvr4x3cGLcsuJX1A',
#   'alias': 'subway-parsons-10',
#   'name': 'Subway',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q9WM8YiBKEUa7d1rJAWNhw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/subway-parsons-10?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 37.340261184653, 'longitude': -95.2669015329527},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2010 Main',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2010 Main', 'Parsons, KS 67357']},
#   'phone': '+16204210677',
#   'display_phone': '(620) 421-0677',
#   'distance': 733.2387099232936},
#  {'id': '0nUn5keTqc1r1-le6OYALQ',
#   'alias': 'taco-bell-parsons',
#   'name': 'Taco Bell',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tvf6E_HWWNqyN1AEzpCOGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-bell-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.342784, 'longitude': -95.258633},
#   'transactions': [],
#   'location': {'address1': '301 N. 16th Street',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['301 N. 16th Street', 'Parsons, KS 67357']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 63.76472589513546},
#  {'id': 'XB254DlJUO6574RJ8m0WDg',
#   'alias': 'petes-parsons',
#   'name': "Pete's",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/petes-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'convenience', 'title': 'Convenience Stores'},
#    {'alias': 'servicestations', 'title': 'Gas Stations'},
#    {'alias': 'delis', 'title': 'Delis'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.3624887, 'longitude': -95.2584143},
#   'transactions': [],
#   'location': {'address1': '2341 N 16th St',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2341 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204218900',
#   'display_phone': '(620) 421-8900',
#   'distance': 2389.271590994242},
#  {'id': 'maf12ER_b5h8IZvWKSkhIw',
#   'alias': 'dos-fronteras-mexican-bar-and-grill-parsons',
#   'name': 'Dos Fronteras Mexican Bar & Grill',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dos-fronteras-mexican-bar-and-grill-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.33993717, 'longitude': -95.28932117},
#   'transactions': [],
#   'location': {'address1': '3400 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3400 Main St', 'Parsons, KS 67357']},
#   'phone': '+16207177437',
#   'display_phone': '(620) 717-7437',
#   'distance': 2682.7830064936356},
#  {'id': '0qo2njhaVSkQA2sRzPmSBQ',
#   'alias': 'c-js-diner-parsons',
#   'name': "C J's Diner",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/c-js-diner-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 37.3399, 'longitude': -95.28686},
#   'transactions': [],
#   'location': {'address1': '3230 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3230 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204215757',
#   'display_phone': '(620) 421-5757',
#   'distance': 2474.209929978479}]

# %%
type(tacos[0])
# Out:
# dict

# %%
tacos
# Out:
# [{'id': 'uVsorDu2ZUVR7a1EPEA7XQ',
#   'alias': 'hickory-hole-parsons',
#   'name': 'Hickory Hole',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sWp-j6nDr7QISXRlRYP2Aw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hickory-hole-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 16,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.340157, 'longitude': -95.245848},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '720 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['720 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204219067',
#   'display_phone': '(620) 421-9067',
#   'distance': 1188.6398072372385},
#  {'id': 'EMy82JTdUU9Tl8m9xlliWQ',
#   'alias': 'kitchen-pass-restaurant-and-bar-parsons',
#   'name': 'Kitchen Pass Restaurant & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cYfFKT-SEM3cSluaEu3tJw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kitchen-pass-restaurant-and-bar-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 24,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.340743, 'longitude': -95.261394},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1711 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1711 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204211907',
#   'display_phone': '(620) 421-1907',
#   'distance': 272.93161261193865},
#  {'id': 'GIOhujdECudw5bMkjcV_hw',
#   'alias': 'el-pueblito-mexican-restaurant-parsons',
#   'name': 'El Pueblito Mexican Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/e5V9puRDh5SeeV-PTmRmVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-pueblito-mexican-restaurant-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.34024, 'longitude': -95.2627399},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1804 Main St',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1804 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204213684',
#   'display_phone': '(620) 421-3684',
#   'distance': 404.1743243221859},
#  {'id': 'XeTVGhNbkvm93W-AXv198A',
#   'alias': 'remnant-cafe-parsons',
#   'name': 'Remnant Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OSdf3-i092j-7M9McfuUEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/remnant-cafe-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 10,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.34079, 'longitude': -95.26177},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1719 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1719 Main St', 'Parsons, KS 67357']},
#   'phone': '+16207174185',
#   'display_phone': '(620) 717-4185',
#   'distance': 304.5547471962812},
#  {'id': 'M3531Fd-KtsYeEAigDbS8A',
#   'alias': 'ernestos-mexican-food-parsons',
#   'name': "Ernesto's Mexican Food",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dPqKew9tT7vG1s3rBnUW1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ernestos-mexican-food-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 20,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.34171, 'longitude': -95.26439},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '200 N Central Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['200 N Central Ave', 'Parsons, KS 67357']},
#   'phone': '+16204212930',
#   'display_phone': '(620) 421-2930',
#   'distance': 480.38317953280824},
#  {'id': 'jTYCQF27aYaujD63p3ZPew',
#   'alias': 'cosmic-castle-parsons',
#   'name': 'Cosmic Castle',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G9U1wnecrELytlh0X9SXbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cosmic-castle-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 5,
#   'categories': [{'alias': 'arcades', 'title': 'Arcades'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.339993027316, 'longitude': -95.2622587233782},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '110 S 18th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['110 S 18th St', 'Parsons, KS 67357']},
#   'phone': '+16207174105',
#   'display_phone': '(620) 717-4105',
#   'distance': 385.31951317525125},
#  {'id': 'R6f-4etSmAzmeFJwpK-haw',
#   'alias': 'big-sky-bistro-parsons',
#   'name': 'Big Sky Bistro',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/big-sky-bistro-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 4,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3401185058406,
#    'longitude': -95.2564059374554},
#   'transactions': [],
#   'location': {'address1': '1500 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1500 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204212710',
#   'display_phone': '(620) 421-2710',
#   'distance': 335.73028653108474},
#  {'id': 'UWr6lC9RKo4R6XT6C4TOPQ',
#   'alias': 'pizzos-corner-parsons',
#   'name': "Pizzo's Corner",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xytWu8gPqj1PjwSjH_g81w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzos-corner-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 15,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3633235880336,
#    'longitude': -95.2589002582759},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2318 N 16th St',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2318 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204231559',
#   'display_phone': '(620) 423-1559',
#   'distance': 2336.5978149472744},
#  {'id': 'mMSPfBNAKNdpSexJRrmC9g',
#   'alias': 'chinese-chef-parsons',
#   'name': 'Chinese Chef',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chinese-chef-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 9,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3493, 'longitude': -95.25958},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '900 N 16th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['900 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204233914',
#   'display_phone': '(620) 423-3914',
#   'distance': 771.8495263767685},
#  {'id': 'KT3_y9NMyd0zj7VDaaUKEg',
#   'alias': 'granny-bs-family-diner-parsons',
#   'name': "Granny B's Family Diner",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_-kXoJWtMZaAu4jgb0VqpA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/granny-bs-family-diner-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.34005, 'longitude': -95.28019},
#   'transactions': [],
#   'location': {'address1': '2930 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2930 Main St', 'Parsons, KS 67357']},
#   'phone': '+16206056111',
#   'display_phone': '(620) 605-6111',
#   'distance': 1892.826876889311},
#  {'id': 'ZLw1CbQLTBfilFhHGobo2Q',
#   'alias': 'hortons-pizza-plus-parsons',
#   'name': 'Hortons Pizza Plus',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Gw9AqfjbFLjTqdM5gTzeeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hortons-pizza-plus-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 6,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 37.3405469398327,
#    'longitude': -95.2528686448932},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1201 Main',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1201 Main', 'Parsons, KS 67357']},
#   'phone': '+16207174174',
#   'display_phone': '(620) 717-4174',
#   'distance': 577.8993219064663},
#  {'id': 'va2Fw3pBhd9Ait5ydWJBNg',
#   'alias': 'shredders-parsons',
#   'name': 'Shredders',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-UZl2vFfpQq5zX7joT4r_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shredders-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 10,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 37.33997, 'longitude': -95.28876},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3330 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3330 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204216823',
#   'display_phone': '(620) 421-6823',
#   'distance': 2642.165708977959},
#  {'id': 'MJ5770PLJJIIyj36xyMJuw',
#   'alias': 'mcdonalds-parsons-4',
#   'name': "McDonald's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/t6HvinaFvr5a3R7cgwLjAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mcdonalds-parsons-4?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 11,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 37.3428193245051,
#    'longitude': -95.2586960792542},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '301 N 16th',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['301 N 16th', 'Parsons, KS 67357']},
#   'phone': '+16204210244',
#   'display_phone': '(620) 421-0244',
#   'distance': 63.355942383949596},
#  {'id': '6cx8_ztzoKPLu-TooqaL3A',
#   'alias': 'chinese-chef-parsons-2',
#   'name': 'Chinese Chef',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chinese-chef-parsons-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.349286, 'longitude': -95.259707},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '400 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['400 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204233914',
#   'display_phone': '(620) 423-3914',
#   'distance': 778.0557730132249},
#  {'id': 'c9_bHcFOT7KoNCSdxDnCOA',
#   'alias': 'taco-mayo-no-81-parsons',
#   'name': 'Taco Mayo No 81',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Pa70uE2rfEASU480G9ETCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-mayo-no-81-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3399, 'longitude': -95.28612},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3210 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3210 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204216296',
#   'display_phone': '(620) 421-6296',
#   'distance': 2411.831069179789},
#  {'id': 'fTekX5M9SaYZqRafXb7igQ',
#   'alias': 'sonic-drive-in-parsons-2',
#   'name': 'Sonic Drive-In',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/quJsFcIgQyQWTQgRBZlvhA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sonic-drive-in-parsons-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 37.3406236, 'longitude': -95.2837503},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3113 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3113 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204215440',
#   'display_phone': '(620) 421-5440',
#   'distance': 2194.461254173005},
#  {'id': 'jkIRuIkSibraDC3pewY0ew',
#   'alias': 'subway-parsons-7',
#   'name': 'Subway',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aNs1ESF06e8XChuWDm6hCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/subway-parsons-7?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3718589666557,
#    'longitude': -95.2553559134621},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '3201 N 16th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3201 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204210999',
#   'display_phone': '(620) 421-0999',
#   'distance': 3301.5682264248317},
#  {'id': 'd6yseqNRFmxVlM0sROFgSg',
#   'alias': 'genko-hibachi-expres-parsons',
#   'name': 'Genko Hibachi Expres',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/genko-hibachi-expres-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.34083, 'longitude': -95.26952},
#   'transactions': [],
#   'location': {'address1': '2209 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2209 Main St', 'Parsons, KS 67357']},
#   'phone': '+16207788930',
#   'display_phone': '(620) 778-8930',
#   'distance': 939.0598108264846},
#  {'id': 'lo_OxhJ4UbhpYiklvb7Xaw',
#   'alias': 'scooters-coffee-parsons',
#   'name': 'scooters coffee',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/scooters-coffee-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 37.3402073423643, 'longitude': -95.258048325777},
#   'transactions': [],
#   'location': {'address1': '1506 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['1506 Main St', 'Parsons, KS 67357']},
#   'phone': '+16206056116',
#   'display_phone': '(620) 605-6116',
#   'distance': 249.04794013599707},
#  {'id': '8KtJ6MNfFnAyITqhNPoMhA',
#   'alias': 'pizza-hut-parsons-2',
#   'name': 'Pizza Hut',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9xAyjld5Xze6KWviJ2Xt3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizza-hut-parsons-2?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 37.3401759, 'longitude': -95.270229},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2230 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2230 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204213720',
#   'display_phone': '(620) 421-3720',
#   'distance': 1019.1211144375114},
#  {'id': 'AGCcO8zvr4x3cGLcsuJX1A',
#   'alias': 'subway-parsons-10',
#   'name': 'Subway',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Q9WM8YiBKEUa7d1rJAWNhw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/subway-parsons-10?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 37.340261184653, 'longitude': -95.2669015329527},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2010 Main',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2010 Main', 'Parsons, KS 67357']},
#   'phone': '+16204210677',
#   'display_phone': '(620) 421-0677',
#   'distance': 733.2387099232936},
#  {'id': '0nUn5keTqc1r1-le6OYALQ',
#   'alias': 'taco-bell-parsons',
#   'name': 'Taco Bell',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tvf6E_HWWNqyN1AEzpCOGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-bell-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.342784, 'longitude': -95.258633},
#   'transactions': [],
#   'location': {'address1': '301 N. 16th Street',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['301 N. 16th Street', 'Parsons, KS 67357']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 63.76472589513546},
#  {'id': 'XB254DlJUO6574RJ8m0WDg',
#   'alias': 'petes-parsons',
#   'name': "Pete's",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/petes-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'convenience', 'title': 'Convenience Stores'},
#    {'alias': 'servicestations', 'title': 'Gas Stations'},
#    {'alias': 'delis', 'title': 'Delis'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.3624887, 'longitude': -95.2584143},
#   'transactions': [],
#   'location': {'address1': '2341 N 16th St',
#    'address2': None,
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['2341 N 16th St', 'Parsons, KS 67357']},
#   'phone': '+16204218900',
#   'display_phone': '(620) 421-8900',
#   'distance': 2389.271590994242},
#  {'id': 'maf12ER_b5h8IZvWKSkhIw',
#   'alias': 'dos-fronteras-mexican-bar-and-grill-parsons',
#   'name': 'Dos Fronteras Mexican Bar & Grill',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dos-fronteras-mexican-bar-and-grill-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.33993717, 'longitude': -95.28932117},
#   'transactions': [],
#   'location': {'address1': '3400 Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3400 Main St', 'Parsons, KS 67357']},
#   'phone': '+16207177437',
#   'display_phone': '(620) 717-7437',
#   'distance': 2682.7830064936356},
#  {'id': '0qo2njhaVSkQA2sRzPmSBQ',
#   'alias': 'c-js-diner-parsons',
#   'name': "C J's Diner",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/c-js-diner-parsons?adjust_creative=ZgQxRTZk4a1F2l5iDXhQgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZgQxRTZk4a1F2l5iDXhQgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 37.3399, 'longitude': -95.28686},
#   'transactions': [],
#   'location': {'address1': '3230 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Parsons',
#    'zip_code': '67357',
#    'country': 'US',
#    'state': 'KS',
#    'display_address': ['3230 Main St', 'Parsons, KS 67357']},
#   'phone': '+16204215757',
#   'display_phone': '(620) 421-5757',
#   'distance': 2474.209929978479}]

# %%
def parse_api_response(data):
    """
    Parse Yelp API results to extract restaurant URLs.
    
    Args:
        data (string): String of properly formatted JSON.

    Returns:
        (list): list of URLs as strings from the input JSON.
    """
    
    data_dict = json.loads(data)
    businesses = data_dict["businesses"]
    result = []
    for i in range(len(businesses)):
        business = businesses[i]
        result.append(business["url"])
    return result

# %%
parse_api_response(all_restaurants(api_key, "tacos"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6e4e1bcac526> in <module>
# ----> 1 parse_api_response(all_restaurants(api_key, "tacos"))
#
# <ipython-input-9-f550b9880620> in parse_api_response(data)
#      10     """
#      11
# ---> 12     data_dict = json.loads(data)
#      13     businesses = data_dict["businesses"]
#      14     result = []
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
def parse_page(html):
    """
    Parse the reviews on a single page of a restaurant.
    
    Args:
        html (string): String of HTML corresponding to a Yelp restaurant

    Returns:
        tuple(list, string): a tuple of two elements
            first element: list of dictionaries corresponding to the extracted review information
            second element: URL for the next page of reviews (or None if it is the last page)
    """
    
    soup = BeautifulSoup(html, 'html.parser')
    
    #print(soup.prettify()) 
    
    review_soups = soup.find_all(itemprop = "review")
    
    count1 = soup.find(itemprop = "reviewCount")
    count = int(count1.get_text().strip())
    num_pages = count//20 + 1
    #print(num_pages)
    
    review_list = []
    for each in review_soups:
        #print(each)
        
        review_info = dict()
        text = each.get_text().strip()
        date = each.find(itemprop = "datePublished").get("content")
        rating = each.find(itemprop = "ratingValue").get("content")
        author = each.find(itemprop = "author").get("content")
        
        review_info['author'] = author
        review_info['rating'] = float(rating)
        review_info['date'] = date
        review_info['description'] = text
        review_list.append(review_info)
        #print(review_info)
        
        
    return (review_list, num_pages)

# %%
def extract_reviews(url):
    """
    Retrieve ALL of the reviews for a single restaurant on Yelp.

    Parameters:
        url (string): Yelp URL corresponding to the restaurant of interest.

    Returns:
        reviews (list): list of dictionaries containing extracted review information
    """
    
    (review_list,num_pages) = parse_page(retrieve_html(url)[1])
    #print(num_pages)
    
    result = review_list
    for i in range(1, num_pages):
        curr_offset = i*20
        add_string = '?start=%d'%curr_offset
        curr_url = url + add_string
        (curr_review_list,num_pages) = parse_page(retrieve_html(curr_url)[1])
        result += curr_review_list
        

        #https://www.yelp.com/biz/larry-and-carols-pizza-pittsburgh?start=20
    
    return result

# %%
extract_reviews('https://www.yelp.com/biz/man-vs-fries-seattle-2?osq=Tacos')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-db26f07504c9> in <module>
# ----> 1 extract_reviews('https://www.yelp.com/biz/man-vs-fries-seattle-2?osq=Tacos')
#
# <ipython-input-11-87003989a710> in extract_reviews(url)
#      10     """
#      11
# ---> 12     (review_list,num_pages) = parse_page(retrieve_html(url)[1])
#      13     #print(num_pages)
#      14
#
# <ipython-input-10-6b2e0c910dd1> in parse_page(html)
#      19
#      20     count1 = soup.find(itemprop = "reviewCount")
# ---> 21     count = int(count1.get_text().strip())
#      22     num_pages = count//20 + 1
#      23     #print(num_pages)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
